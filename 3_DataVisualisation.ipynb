# %%
import matplotlib.pyplot as plt

squares = [1,4,9,16,25,3]

figure, axis = plt.subplots()
# axis.plot(squares)
# axis.plot(squares, linewidth=3)

axis.set_title("Squared numbers", fontsize=20)
# axis.plot(squares, linewidth=3)

axis.set_xlabel("Value", fontsize=14)
axis.set_ylabel("Square", fontsize=14)
# axis.plot(squares, linewidth=3)

axis.tick_params(axis='both', labelsize=8) # Setting the values size
axis.plot(squares, linewidth=3)

plt.show()

# %%
plt.show()

# %%
x_values = [1,2,3,4,5]
y_values = [x_val**2 for x_val in x_values]
y_values
# Out:
# [1, 4, 9, 16, 25]

# %%
figure, axis = plt.subplots()

axis.plot(x_values, y_values, linewidth=4)
plt.show()

# %%
figure, axis = plt.subplots()

x_values = [1,2,3,4,5]
y_values = [x_val**2 for x_val in x_values]
del y_values[0]

same_length = len(x_values) == len(y_values)
print(f"Length same? {same_length}")

try:
    axis.plot(x_values, y_values, linewidth=4)
    plt.show()
except ValueError as ve:
    if "x and y must have same first dimension" in str(ve):
        print("Invalid dimensions!")
# Out:
# Length same? False
# Invalid dimensions!

# %%
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
x_values = [1,2,3,4,5]
y_values = [x_val**2 for x_val in x_values]
figure, axis = plt.subplots()
axis.plot(x_values, y_values, linewidth=4)

plt.style.use('seaborn-v0_8') # NOTE: Just 'seaborn' may not work here, so you should check itt with plt.style.available

plt.show()

# %%
x_values = [1,2,3,4,5]
y_values = [x_val**2 for x_val in x_values]

figure, axis = plt.subplots()
axis.scatter(x_values, y_values, s=100)

plt.style.use('seaborn-v0_8') # NOTE: Just 'seaborn' may not work here, so you should check itt with plt.style.available

plt.show()

# %%
x_values = [1,2,3,4,5]
y_values = [x_val**2 for x_val in x_values]

figure, axis = plt.subplots()
# axis.scatter(x_values, y_values, s=100, color='red')
axis.scatter(x_values, y_values, s=100, color=(0.0,0.8,0.0)) # 2nd way of specifying color: c=(0, 0.8, 0)
plt.style.use('seaborn-v0_8') # NOTE: Just 'seaborn' may not work here, so you should check itt with plt.style.available

plt.show()

# %%
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

figure, axis = plt.subplots()
# axis.scatter(x_values, y_values, s=100, color='red')
axis.scatter(x_values, y_values, s=10, c=y_values, cmap=plt.cm.Blues) # 2nd way of specifying color: c=(0, 0.8, 0)

plt.show()

# %%
import random

class RandomWalk:

    def __init__(self, num_of_points=5000):
        self.num_points = num_of_points

        # START point
        self.x_values = [0]
        self.y_values = [0]

    def walk(self):

        # check if we are not out of scope (and canvas)
        while len(self.x_values) < self.num_points:

            random_direction_x = self.get_random_direction()
            random_distance_x = self.get_random_distance()
            step_x = random_direction_x * random_distance_x

            random_direction_y = self.get_random_direction()
            random_distance_y = self.get_random_distance()
            step_y = random_direction_y * random_distance_y


        # new position:
        x_old = self.x_values[-1] # the last value (the most recent step)
        x_new = x_old + x_step
        y_old = self.x_values[-1] # the last value (the most recent step)
        y_new = y_old + y_step

        self.x_values.append(x_new)
        self.y_values.append(y_new)

    def get_random_direction(self, min=-1, max=1):
        return random.choice([min, max])
        
    def get_random_distance(self, min=1, max=4, step=1):
        return random.choice(range(min,max,step))

# %%
random_walk = RandomWalk()
random_walk.walk()

# %%
plt.style.use('classic')
fig, axis = plt.subplots()
axis.scatter(random_walk.x_values, random_walk.x_values, s=15)

plt.show()
