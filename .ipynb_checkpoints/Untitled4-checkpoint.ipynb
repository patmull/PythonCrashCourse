# %%
import csv

filename = 'data/sitka_weather_07-2018_simple.csv'

# Getting the header rows
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)

    for index, column_header in enumerate(header_row):
        print(index, column_header)

    # High temperatures
    highs = []
    for row in reader:
        high = int(row[5]) # the max temperatore column (see above the index 5)
        highs.append(high)

print(highs)
# Out:
# ['STATION', 'NAME', 'DATE', 'PRCP', 'TAVG', 'TMAX', 'TMIN']
# 0 STATION
# 1 NAME
# 2 DATE
# 3 PRCP
# 4 TAVG
# 5 TMAX
# 6 TMIN
# [62, 58, 70, 70, 67, 59, 58, 62, 66, 59, 56, 63, 65, 58, 56, 59, 64, 60, 60, 61, 65, 65, 63, 59, 64, 65, 68, 66, 64, 67, 65]

# %%
# plotting the temperature chart
import matplotlib.pyplot as plt

# TODO: Convert to Celsius

# the high temperqatures
plt.style.use('seaborn-v0_8') # See tha avilable styles: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
fig, axis = plt.subplots()
axis.plot(highs, c='red') # seaborn automatically plots the values to an y-axis and creates the numbering (the "days") to the x axis 

# Plot formatting
plt.title("Daily high temp, July 2018", fontsize=24)
plt.xlabel('Days', fontsize=16)
plt.ylabel("Temperature [F]:", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

plt.show()

# %%
# PROBLEM: We can't see the exact days aboe. 
# SOLUTION: We can generate the dates based on the starting date
# E.g.
from datetime import datetime

first_date = datetime.strptime('2018-07-01', '%Y-%m-%d')
first_date
# Out:
# datetime.datetime(2018, 7, 1, 0, 0)

# %%
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    print(header_row)

    dates, highs, lows = [], [], [] # we will also add lows this time

    for line in reader:
    
        current_date = datetime.strptime(line[2], '%Y-%m-%d') # The second 'column' (value from the list) on the actual read line
        dates.append(current_date)

        high = int(line[5])
        highs.append(high)

        low = int(line[6])
        lows.append(low)

# the high temperqatures
plt.style.use('seaborn-v0_8')
fig, axis = plt.subplots()
axis.plot(dates, highs, c='red')
axis.plot(dates, lows, c='blue')
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1) # alpha = transparency

# Plot formatting
plt.title("Daily high and low temp, July 2018", fontsize=24)
plt.xlabel('Date', fontsize=16)
fig.autofmt_xdate() # auto formatter of the date # TODO: Comment this to see what it does.
plt.ylabel("Temperature [F]:", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)

plt.show()
# Out:
# ['STATION', 'NAME', 'DATE', 'PRCP', 'TAVG', 'TMAX', 'TMIN']

# %%
## Earthquake data
import json

file_earthquakes = 'data/2_5_week.geojson'
with open(file_earthquakes, encoding='utf-8') as f:
    loaded_earthquake_data = json.load(f)

# NOTE: This may be unnecessarry
readable_file = 'data/readable_eq_data.json'
with open(readable_file, 'w') as f:
    json.dump(loaded_earthquake_data, f, indent=4)

loaded_earthquake_data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1702559275000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 320},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '51 km ESE of Cantwell, Alaska',
#     'time': 1702556706982,
#     'updated': 1702556810168,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fzqbcis',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fzqbcis.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'ak',
#     'code': '023fzqbcis',
#     'ids': ',ak023fzqbcis,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.6,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 51 km ESE of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.0612, 63.1641, 62.6]},
#    'id': 'ak023fzqbcis'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.91,
#     'place': '19 km SW of Stella, Puerto Rico',
#     'time': 1702555115050,
#     'updated': 1702557807710,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433888',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433888.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 130,
#     'net': 'pr',
#     'code': '71433888',
#     'ids': ',pr71433888,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 4,
#     'dmin': 0.1877,
#     'rms': 0.15,
#     'gap': 211,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 19 km SW of Stella, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.3911666666667, 18.2155, 7.75]},
#    'id': 'pr71433888'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '44 km ENE of Barcelona, Philippines',
#     'time': 1702554840941,
#     'updated': 1702556924040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liy7',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liy7.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liy7',
#     'ids': ',us7000liy7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 32,
#     'dmin': 1.72,
#     'rms': 1.05,
#     'gap': 126,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 44 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8124, 8.288, 66.56]},
#    'id': 'us7000liy7'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '46 km ENE of Barcelona, Philippines',
#     'time': 1702554360474,
#     'updated': 1702556022040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liy8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liy8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '7000liy8',
#     'ids': ',us7000liy8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 1.769,
#     'rms': 0.84,
#     'gap': 138,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 46 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.7907, 8.3776, 57.942]},
#    'id': 'us7000liy8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '50 km ENE of Barcelona, Philippines',
#     'time': 1702550573468,
#     'updated': 1702552292040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lixx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lixx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lixx',
#     'ids': ',us7000lixx,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': 1.763,
#     'rms': 0.86,
#     'gap': 88,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 50 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8786, 8.2815, 59.486]},
#    'id': 'us7000lixx'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.52,
#     'place': '7 km ENE of Mayagüez, Puerto Rico',
#     'time': 1702550072930,
#     'updated': 1702558140179,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2023348000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2023348000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'pr',
#     'code': '2023348000',
#     'ids': ',pr2023348000,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 3,
#     'dmin': 0.2216,
#     'rms': 0.18,
#     'gap': 279,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 7 km ENE of Mayagüez, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0786, 18.2258, 12]},
#    'id': 'pr2023348000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'southern East Pacific Rise',
#     'time': 1702546184089,
#     'updated': 1702550490040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000livw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000livw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000livw',
#     'ids': ',us7000livw,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 29,
#     'dmin': 27.632,
#     'rms': 0.75,
#     'gap': 124,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - southern East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.7493, -56.0214, 10]},
#    'id': 'us7000livw'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.54,
#     'place': '10 km ENE of Petrolia, CA',
#     'time': 1702543273400,
#     'updated': 1702549635121,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73976006',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73976006.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 99,
#     'net': 'nc',
#     'code': '73976006',
#     'ids': ',nc73976006,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.04656,
#     'rms': 0.09,
#     'gap': 74,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 10 km ENE of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.1681671, 40.3515015, 22.93]},
#    'id': 'nc73976006'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '2 km WSW of Indios, Puerto Rico',
#     'time': 1702543064250,
#     'updated': 1702543658680,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433883',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433883.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'pr',
#     'code': '71433883',
#     'ids': ',pr71433883,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.03651,
#     'rms': 0.18,
#     'gap': 173,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 2 km WSW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8411666666667, 17.9895, 15.74]},
#    'id': 'pr71433883'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '13 km SW of Khalmion, Kyrgyzstan',
#     'time': 1702540793045,
#     'updated': 1702542323040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000livf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000livf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000livf',
#     'ids': ',us7000livf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.539,
#     'rms': 0.6,
#     'gap': 94,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 13 km SW of Khalmion, Kyrgyzstan'},
#    'geometry': {'type': 'Point', 'coordinates': [71.5122, 40.1392, 10]},
#    'id': 'us7000livf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '71 km SW of Pelabuhanratu, Indonesia',
#     'time': 1702538836338,
#     'updated': 1702540630040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liv9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liv9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000liv9',
#     'ids': ',us7000liv9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 53,
#     'dmin': 1.617,
#     'rms': 0.78,
#     'gap': 119,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 71 km SW of Pelabuhanratu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [106.0231, -7.3556, 56.624]},
#    'id': 'us7000liv9'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.79,
#     'place': '6 km S of Volcano, Hawaii',
#     'time': 1702537249740,
#     'updated': 1702552415114,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73684747',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73684747.geojson',
#     'felt': 2,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 120,
#     'net': 'hv',
#     'code': '73684747',
#     'ids': ',hv73684747,us7000liv7,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 33,
#     'dmin': None,
#     'rms': 0.280000001,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 6 km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2431640625, 19.386833190918, 0.939999997615814]},
#    'id': 'hv73684747'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': 'northern Mid-Atlantic Ridge',
#     'time': 1702536725137,
#     'updated': 1702538300040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liv6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liv6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000liv6',
#     'ids': ',us7000liv6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 64,
#     'dmin': 13.517,
#     'rms': 0.89,
#     'gap': 149,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - northern Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-46.3575, 17.2185, 10]},
#    'id': 'us7000liv6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '65 km SW of Ashkāsham, Afghanistan',
#     'time': 1702533896344,
#     'updated': 1702539470040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000liuz',
#     'ids': ',us7000liuz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 2.357,
#     'rms': 0.64,
#     'gap': 102,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 65 km SW of Ashkāsham, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [71.0523, 36.2362, 112.016]},
#    'id': 'us7000liuz'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '97 km ENE of Barcelona, Philippines',
#     'time': 1702533316874,
#     'updated': 1702537293040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liux',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liux.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liux',
#     'ids': ',us7000liux,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 2.209,
#     'rms': 0.44,
#     'gap': 112,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 97 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.2153, 8.5806, 10]},
#    'id': 'us7000liux'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '97 km E of Marihatag, Philippines',
#     'time': 1702532002509,
#     'updated': 1702536254040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liuu',
#     'ids': ',us7000liuu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': 2.246,
#     'rms': 0.53,
#     'gap': 128,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 97 km E of Marihatag, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.1705, 8.6793, 10]},
#    'id': 'us7000liuu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '88 km ENE of Barcelona, Philippines',
#     'time': 1702531600540,
#     'updated': 1702533806040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lius',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lius.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lius',
#     'ids': ',us7000lius,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 61,
#     'dmin': 2.134,
#     'rms': 0.62,
#     'gap': 122,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 88 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.1227, 8.5672, 10]},
#    'id': 'us7000lius'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '67 km SW of Tupiza, Bolivia',
#     'time': 1702530294553,
#     'updated': 1702531606040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lium',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lium.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000lium',
#     'ids': ',us7000lium,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 2.13,
#     'rms': 0.52,
#     'gap': 79,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 67 km SW of Tupiza, Bolivia'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.2141, -21.8368, 251.836]},
#    'id': 'us7000lium'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '238 km SE of Chiniak, Alaska',
#     'time': 1702526424323,
#     'updated': 1702528908040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000liuf',
#     'ids': ',ak023fzlek7t,us7000liuf,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': 109,
#     'dmin': 2.379,
#     'rms': 0.76,
#     'gap': 145,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 238 km SE of Chiniak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4338, 56.1479, 17.797]},
#    'id': 'us7000liuf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '86 km ENE of Barcelona, Philippines',
#     'time': 1702524998048,
#     'updated': 1702526069040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liuc',
#     'ids': ',us7000liuc,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 2.092,
#     'rms': 0.59,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 86 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.152, 8.4738, 65.664]},
#    'id': 'us7000liuc'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '6 km SSE of Qingsheng, China',
#     'time': 1702521543660,
#     'updated': 1702525053027,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liua',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liua.geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000liua',
#     'ids': ',us7000liua,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 39,
#     'dmin': 6.85,
#     'rms': 0.7,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 6 km SSE of Qingsheng, China'},
#    'geometry': {'type': 'Point', 'coordinates': [105.5421, 29.2665, 38.715]},
#    'id': 'us7000liua'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.94,
#     'place': '7 km SW of Volcano, Hawaii',
#     'time': 1702520751480,
#     'updated': 1702521975123,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73684282',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73684282.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 133,
#     'net': 'hv',
#     'code': '73684282',
#     'ids': ',hv73684282,us7000liu7,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 38,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 67,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 7 km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.277333333333, 19.3836666666667, 1.44]},
#    'id': 'hv73684282'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.64,
#     'place': '6 km SW of Volcano, Hawaii',
#     'time': 1702520234170,
#     'updated': 1702520565340,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73684257',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73684257.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 107,
#     'net': 'hv',
#     'code': '73684257',
#     'ids': ',hv73684257,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 36,
#     'dmin': None,
#     'rms': 0.239999995,
#     'gap': 41,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 6 km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.272506713867, 19.3933334350586, 0.990000009536743]},
#    'id': 'hv73684257'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '16 km NE of Hermleigh, Texas',
#     'time': 1702517316105,
#     'updated': 1702518829865,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023ykcm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023ykcm.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'tx',
#     'code': '2023ykcm',
#     'ids': ',tx2023ykcm,us7000litw,',
#     'sources': ',tx,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 80,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 16 km NE of Hermleigh, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-100.647, 32.753, 8.4369]},
#    'id': 'tx2023ykcm'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '17 km NE of Hermleigh, Texas',
#     'time': 1702516488318,
#     'updated': 1702523256512,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023ykca',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023ykca.geojson',
#     'felt': 6,
#     'cdi': 4.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 225,
#     'net': 'tx',
#     'code': '2023ykca',
#     'ids': ',tx2023ykca,us7000lits,',
#     'sources': ',tx,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 80,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 17 km NE of Hermleigh, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-100.642, 32.758, 7.85]},
#    'id': 'tx2023ykca'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '53 km SW of Modisi, Indonesia',
#     'time': 1702515949758,
#     'updated': 1702516908040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000litr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000litr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000litr',
#     'ids': ',us7000litr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 76,
#     'dmin': 1.747,
#     'rms': 1.09,
#     'gap': 52,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 53 km SW of Modisi, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [124.0674, 0.1386, 107.163]},
#    'id': 'us7000litr'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.23,
#     'place': '89 km N of Brenas, Puerto Rico',
#     'time': 1702513327340,
#     'updated': 1702521040163,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433868',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433868.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 161,
#     'net': 'pr',
#     'code': '71433868',
#     'ids': ',pr71433868,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.9502,
#     'rms': 0.14,
#     'gap': 246,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 89 km N of Brenas, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.3581666666667, 19.274, 20.26]},
#    'id': 'pr71433868'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '92 km SSE of Alo, Wallis and Futuna',
#     'time': 1702510511291,
#     'updated': 1702511604040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lit3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lit3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000lit3',
#     'ids': ',us7000lit3,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': 4.816,
#     'rms': 0.84,
#     'gap': 115,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 92 km SSE of Alo, Wallis and Futuna'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-177.7606, -15.0746, 381.121]},
#    'id': 'us7000lit3'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '181 km WSW of Port Orford, Oregon',
#     'time': 1702505844857,
#     'updated': 1702510796040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lisu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lisu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 222,
#     'net': 'us',
#     'code': '7000lisu',
#     'ids': ',us7000lisu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 64,
#     'dmin': 1.697,
#     'rms': 0.54,
#     'gap': 250,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 181 km WSW of Port Orford, Oregon'},
#    'geometry': {'type': 'Point', 'coordinates': [-126.6367, 42.3439, 12.259]},
#    'id': 'us7000lisu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '91 km WSW of Copiapó, Chile',
#     'time': 1702502755365,
#     'updated': 1702507249040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liru',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liru.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000liru',
#     'ids': ',us7000liru,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.478,
#     'rms': 0.62,
#     'gap': 191,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 91 km WSW of Copiapó, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1665, -27.7319, 30.508]},
#    'id': 'us7000liru'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '255 km S of Vailoatai, American Samoa',
#     'time': 1702498977042,
#     'updated': 1702542782126,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lirg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lirg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000lirg',
#     'ids': ',us7000lirg,',
#     'sources': ',us,',
#     'types': ',oaf,origin,phase-data,',
#     'nst': 45,
#     'dmin': 2.43,
#     'rms': 0.77,
#     'gap': 110,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 255 km S of Vailoatai, American Samoa'},
#    'geometry': {'type': 'Point', 'coordinates': [-170.9942, -16.6549, 3.095]},
#    'id': 'us7000lirg'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'Norwegian Sea',
#     'time': 1702498810818,
#     'updated': 1702506274043,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lire',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lire.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000lire',
#     'ids': ',us7000lire,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 103,
#     'dmin': 6.49,
#     'rms': 0.77,
#     'gap': 29,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - Norwegian Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [3.4844, 72.5721, 10]},
#    'id': 'us7000lire'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': 'Norwegian Sea',
#     'time': 1702495846888,
#     'updated': 1702496891040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lir5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lir5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 432,
#     'net': 'us',
#     'code': '7000lir5',
#     'ids': ',us7000lir5,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 145,
#     'dmin': 6.509,
#     'rms': 0.85,
#     'gap': 34,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.3 - Norwegian Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [3.45, 72.5552, 10]},
#    'id': 'us7000lir5'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.61,
#     'place': '3 km ENE of Pāhala, Hawaii',
#     'time': 1702490206540,
#     'updated': 1702504237030,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73683582',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73683582.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 105,
#     'net': 'hv',
#     'code': '73683582',
#     'ids': ',hv73683582,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 124,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 3 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.443, 19.2101666666667, 34.82]},
#    'id': 'hv73683582'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.92,
#     'place': '11 km SW of Volcano, Hawaii',
#     'time': 1702486224450,
#     'updated': 1702509969040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73683477',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73683477.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 131,
#     'net': 'hv',
#     'code': '73683477',
#     'ids': ',us7000liq5,hv73683477,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': None,
#     'rms': 0.09,
#     'gap': 100,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 11 km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.301, 19.3596666666667, 2.18]},
#    'id': 'hv73683477'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '96 km NNW of Batang, Indonesia',
#     'time': 1702483739523,
#     'updated': 1702510965040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liq0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liq0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000liq0',
#     'ids': ',us7000liq0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 3.284,
#     'rms': 0.9,
#     'gap': 42,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 96 km NNW of Batang, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [110.4186, -5.6571, 551.302]},
#    'id': 'us7000liq0'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.7,
#     'place': '48 km W of Mentone, Texas',
#     'time': 1702482478968,
#     'updated': 1702483441040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023yjji',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023yjji.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 211,
#     'net': 'tx',
#     'code': '2023yjji',
#     'ids': ',us7000lipx,tx2023yjji,',
#     'sources': ',us,tx,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 72,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 48 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.112, 31.738, 7.0056]},
#    'id': 'tx2023yjji'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '6 km S of Volcano, Hawaii',
#     'time': 1702478018170,
#     'updated': 1702488584510,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73683272',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73683272.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'hv',
#     'code': '73683272',
#     'ids': ',hv73683272,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': None,
#     'rms': 0.1,
#     'gap': 77,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 6 km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.243833333333, 19.3871666666667, 1.64]},
#    'id': 'hv73683272'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '222 km NE of Lospalos, Timor Leste',
#     'time': 1702477853172,
#     'updated': 1702481817040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lipp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lipp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lipp',
#     'ids': ',us7000lipp,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 83,
#     'dmin': 3.084,
#     'rms': 0.85,
#     'gap': 51,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 222 km NE of Lospalos, Timor Leste'},
#    'geometry': {'type': 'Point', 'coordinates': [128.6454, -7.3596, 147.747]},
#    'id': 'us7000lipp'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '54 km NNE of Chase, Alaska',
#     'time': 1702473908561,
#     'updated': 1702555842040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fy3dfs8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fy3dfs8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '023fy3dfs8',
#     'ids': ',us7000lime,ak023fy3dfs8,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.77,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 54 km NNE of Chase, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.5878, 62.8783, 0]},
#    'id': 'ak023fy3dfs8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '19 km NNE of Kandrian, Papua New Guinea',
#     'time': 1702469553375,
#     'updated': 1702470615040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lim6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lim6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000lim6',
#     'ids': ',us7000lim6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 3.145,
#     'rms': 0.92,
#     'gap': 121,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 19 km NNE of Kandrian, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [149.6001, -6.0387, 63.877]},
#    'id': 'us7000lim6'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.53,
#     'place': '16 km ENE of Wailua, Hawaii',
#     'time': 1702463193210,
#     'updated': 1702557974040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73682967',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73682967.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'hv',
#     'code': '73682967',
#     'ids': ',us7000lirv,hv73682967,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 32,
#     'dmin': None,
#     'rms': 0.27,
#     'gap': 220,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 16 km ENE of Wailua, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.997666666667, 20.9263333333333, 34.24]},
#    'id': 'hv73682967'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '39 km WSW of Mentone, Texas',
#     'time': 1702462725724,
#     'updated': 1702496029862,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023yiym',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023yiym.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2023yiym',
#     'ids': ',tx2023yiym,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 54,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 39 km WSW of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.012, 31.634, 5.656]},
#    'id': 'tx2023yiym'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.08,
#     'place': '2 km SSE of Magas Arriba, Puerto Rico',
#     'time': 1702461347160,
#     'updated': 1702462569620,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433838',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433838.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 146,
#     'net': 'pr',
#     'code': '71433838',
#     'ids': ',pr71433838,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.03921,
#     'rms': 0.17,
#     'gap': 167,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 2 km SSE of Magas Arriba, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.7573333333333, 17.998, 12.41]},
#    'id': 'pr71433838'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '111 km NNE of Finschhafen, Papua New Guinea',
#     'time': 1702455206651,
#     'updated': 1702457134040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lil8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lil8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lil8',
#     'ids': ',us7000lil8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 3.889,
#     'rms': 0.94,
#     'gap': 50,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 111 km NNE of Finschhafen, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [148.3144, -5.6633, 170.313]},
#    'id': 'us7000lil8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '57 km NE of Bandar-e Lengeh, Iran',
#     'time': 1702452785082,
#     'updated': 1702456623040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lil6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lil6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000lil6',
#     'ids': ',us7000lil6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 2.112,
#     'rms': 0.64,
#     'gap': 109,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 57 km NE of Bandar-e Lengeh, Iran'},
#    'geometry': {'type': 'Point', 'coordinates': [55.3048, 26.9039, 10]},
#    'id': 'us7000lil6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '144 km N of Cruz Bay, U.S. Virgin Islands',
#     'time': 1702451832100,
#     'updated': 1702454037040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2023347000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2023347000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'pr',
#     'code': '2023347000',
#     'ids': ',us7000lil2,pr2023347000,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 1.211,
#     'rms': 0.35,
#     'gap': 288,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 144 km N of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.587, 19.6256, 62]},
#    'id': 'pr2023347000'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '2 km NNE of The Geysers, CA',
#     'time': 1702450339610,
#     'updated': 1702490551188,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73975501',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73975501.geojson',
#     'felt': 24,
#     'cdi': 3.8,
#     'mmi': 4.272,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 198,
#     'net': 'nc',
#     'code': '73975501',
#     'ids': ',nc73975501,us7000likr,',
#     'sources': ',nc,us,',
#     'types': ',dyfi,focal-mechanism,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shakemap,',
#     'nst': 109,
#     'dmin': 0.01136,
#     'rms': 0.07,
#     'gap': 26,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 2 km NNE of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.746, 38.7968333, 0.34]},
#    'id': 'nc73975501'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'Volcano Islands, Japan region',
#     'time': 1702449607456,
#     'updated': 1702452029040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000likz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000likz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000likz',
#     'ids': ',us7000likz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 13.041,
#     'rms': 0.96,
#     'gap': 95,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - Volcano Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [142.525, 23.0918, 10.36]},
#    'id': 'us7000likz'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.4,
#     'place': 'southern East Pacific Rise',
#     'time': 1702439750436,
#     'updated': 1702526359158,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lik3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lik3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 449,
#     'net': 'us',
#     'code': '7000lik3',
#     'ids': ',us7000lik3,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': 51,
#     'dmin': 39.039,
#     'rms': 0.59,
#     'gap': 113,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.4 - southern East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.0832, -25.5803, 10]},
#    'id': 'us7000lik3'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '134 km S of Isangel, Vanuatu',
#     'time': 1702436660327,
#     'updated': 1702437688040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lijx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lijx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000lijx',
#     'ids': ',us7000lijx,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 2.611,
#     'rms': 0.9,
#     'gap': 163,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 134 km S of Isangel, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [169.4222, -20.7494, 35]},
#    'id': 'us7000lijx'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'Reykjanes Ridge',
#     'time': 1702436316402,
#     'updated': 1702439034040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lik1',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lik1.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lik1',
#     'ids': ',us7000lik1,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': 24.22,
#     'rms': 0.54,
#     'gap': 113,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - Reykjanes Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-34.438, 56.6366, 10]},
#    'id': 'us7000lik1'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.99,
#     'place': '33 km NNW of Challis, Idaho',
#     'time': 1702435218690,
#     'updated': 1702483894660,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb90036128',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb90036128.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'mb',
#     'code': '90036128',
#     'ids': ',mb90036128,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 49,
#     'dmin': 0.4545,
#     'rms': 0.23,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 33 km NNW of Challis, Idaho'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-114.407666666667, 44.7746666666667, 11.97]},
#    'id': 'mb90036128'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '62 km S of Whites City, New Mexico',
#     'time': 1702432232543,
#     'updated': 1702487517238,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023yiht',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023yiht.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2023yiht',
#     'ids': ',tx2023yiht,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 24,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 62 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.497, 31.624, 7.417]},
#    'id': 'tx2023yiht'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '51 km SSW of Whites City, New Mexico',
#     'time': 1702422336052,
#     'updated': 1702509176551,
#     'tz': None,
# ...
#    'id': 'us7000lh76'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '47 km S of Yakutat, Alaska',
#     'time': 1701984948048,
#     'updated': 1701985550040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023foaz1v8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023foaz1v8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'ak',
#     'code': '023foaz1v8',
#     'ids': ',us7000lh66,ak023foaz1v8,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.59,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 47 km S of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-139.8578, 59.1298, 9.1]},
#    'id': 'ak023foaz1v8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '157 km NNW of Las Khorey, Somalia',
#     'time': 1701981799094,
#     'updated': 1701984482040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh5r',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh5r.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lh5r',
#     'ids': ',us7000lh5r,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 60,
#     'dmin': 4.599,
#     'rms': 0.45,
#     'gap': 99,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 157 km NNW of Las Khorey, Somalia'},
#    'geometry': {'type': 'Point', 'coordinates': [47.465, 12.3893, 10]},
#    'id': 'us7000lh5r'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.56,
#     'place': '1 km S of Banning, CA',
#     'time': 1701979913050,
#     'updated': 1702217787040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40617352',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40617352.geojson',
#     'felt': 6,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 103,
#     'net': 'ci',
#     'code': '40617352',
#     'ids': ',ci40617352,us7000lh57,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 100,
#     'dmin': 0.07825,
#     'rms': 0.16,
#     'gap': 22,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 1 km S of Banning, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.878, 33.9186667, 9.97]},
#    'id': 'ci40617352'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': '10 km NNE of Chiautla de Tapia, Mexico',
#     'time': 1701979418206,
#     'updated': 1702402064637,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh50',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh50.geojson',
#     'felt': 198,
#     'cdi': 8.1,
#     'mmi': 5.293,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 678,
#     'net': 'us',
#     'code': '7000lh50',
#     'ids': ',us7000lh50,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 175,
#     'dmin': 0.82,
#     'rms': 0.64,
#     'gap': 99,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - 10 km NNE of Chiautla de Tapia, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-98.5503, 18.3866, 44.388]},
#    'id': 'us7000lh50'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '66 km E of Marihatag, Philippines',
#     'time': 1701977244980,
#     'updated': 1701987692045,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh4x',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh4x.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000lh4x',
#     'ids': ',us7000lh4x,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 37,
#     'dmin': 2.112,
#     'rms': 0.51,
#     'gap': 154,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 66 km E of Marihatag, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8955, 8.7418, 58.314]},
#    'id': 'us7000lh4x'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': 'Kermadec Islands region',
#     'time': 1701976335075,
#     'updated': 1701978155040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh4u',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh4u.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 416,
#     'net': 'us',
#     'code': '7000lh4u',
#     'ids': ',us7000lh4u,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 1.979,
#     'rms': 1.09,
#     'gap': 173,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.2 - Kermadec Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.1087, -31.241, 10]},
#    'id': 'us7000lh4u'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.43,
#     'place': '78 km SSW of Mākena, Hawaii',
#     'time': 1701975255910,
#     'updated': 1701981400040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73676237',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73676237.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 181,
#     'net': 'hv',
#     'code': '73676237',
#     'ids': ',hv73676237,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 53,
#     'dmin': None,
#     'rms': 0.18,
#     'gap': 304,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 78 km SSW of Mākena, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-156.760333333333, 20.0155, 38.06]},
#    'id': 'hv73676237'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.63,
#     'place': 'Island of Hawaii, Hawaii',
#     'time': 1701969216550,
#     'updated': 1702072659784,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73675997',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73675997.geojson',
#     'felt': 69,
#     'cdi': 3.4,
#     'mmi': 4.101,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 226,
#     'net': 'hv',
#     'code': '73675997',
#     'ids': ',hv73675997,us7000lh41,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 24,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 163,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - Island of Hawaii, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.3855, 19.2466666666667, 32.85]},
#    'id': 'hv73675997'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '24 km S of Denali National Park, Alaska',
#     'time': 1701966892256,
#     'updated': 1702149684040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fo7zofm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fo7zofm.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '023fo7zofm',
#     'ids': ',us7000lgyc,ak023fo7zofm,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.68,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 24 km S of Denali National Park, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.7765, 63.3238, 0]},
#    'id': 'ak023fo7zofm'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'Bonin Islands, Japan region',
#     'time': 1701965115195,
#     'updated': 1701968981040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgy8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgy8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lgy8',
#     'ids': ',us7000lgy8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 8.724,
#     'rms': 0.44,
#     'gap': 156,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - Bonin Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [142.5971, 28.6173, 10]},
#    'id': 'us7000lgy8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '272 km N of Tobelo, Indonesia',
#     'time': 1701963485751,
#     'updated': 1701972127040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000lgxv',
#     'ids': ',us7000lgxv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 3.422,
#     'rms': 0.49,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 272 km N of Tobelo, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [127.8335, 4.1846, 116.281]},
#    'id': 'us7000lgxv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '68 km NW of Lecherías, Venezuela',
#     'time': 1701962615923,
#     'updated': 1701983268401,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxw.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000lgxw',
#     'ids': ',us7000lgxw,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 46,
#     'dmin': 5.591,
#     'rms': 0.73,
#     'gap': 64,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 68 km NW of Lecherías, Venezuela'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.0735, 10.6797, 10]},
#    'id': 'us7000lgxw'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '106 km ENE of Angoram, Papua New Guinea',
#     'time': 1701961812503,
#     'updated': 1702148842040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxs',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxs.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000lgxs',
#     'ids': ',us7000lgxs,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 80,
#     'dmin': 4.372,
#     'rms': 0.65,
#     'gap': 69,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 106 km ENE of Angoram, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [144.932, -3.6526, 10]},
#    'id': 'us7000lgxs'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '51 km ENE of Hinatuan, Philippines',
#     'time': 1701961718582,
#     'updated': 1701964597040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lgxq',
#     'ids': ',us7000lgxq,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 123,
#     'dmin': 1.877,
#     'rms': 0.88,
#     'gap': 81,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 51 km ENE of Hinatuan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.7696, 8.5387, 52.726]},
#    'id': 'us7000lgxq'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '71 km SE of Taoluo, China',
#     'time': 1701961306153,
#     'updated': 1702147397040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000lgxu',
#     'ids': ',us7000lgxu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 122,
#     'dmin': 5.977,
#     'rms': 0.69,
#     'gap': 73,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 71 km SE of Taoluo, China'},
#    'geometry': {'type': 'Point', 'coordinates': [119.9504, 34.8443, 10]},
#    'id': 'us7000lgxu'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '132 km NW of Las Khorey, Somalia',
#     'time': 1701960542089,
#     'updated': 1701961448040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000lgxl',
#     'ids': ',us7000lgxl,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 4.616,
#     'rms': 1.03,
#     'gap': 137,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 132 km NW of Las Khorey, Somalia'},
#    'geometry': {'type': 'Point', 'coordinates': [47.5191, 12.1512, 10]},
#    'id': 'us7000lgxl'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '23 km ENE of Hinatuan, Philippines',
#     'time': 1701958297687,
#     'updated': 1701962249040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxi.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000lgxi',
#     'ids': ',us7000lgxi,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 1.658,
#     'rms': 0.78,
#     'gap': 130,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 23 km ENE of Hinatuan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5341, 8.4399, 76.878]},
#    'id': 'us7000lgxi'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '48 km SE of Port Graham, Alaska',
#     'time': 1701954652211,
#     'updated': 1701961706040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fo628g5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fo628g5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'ak',
#     'code': '023fo628g5',
#     'ids': ',us7000lgws,ak023fo628g5,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.65,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 48 km SE of Port Graham, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2231, 59.043, 37.6]},
#    'id': 'ak023fo628g5'}],
#  'bbox': [-179.2278, -60.3806, -0.13, 179.2842, 72.5721, 569.73]}

# %%
# NOTE: This may be unnecessarry
file_earthquakes = 'data/readable_eq_data.json'

with open(file_earthquakes, encoding='utf-8') as f:
    loaded_earthquake_data = json.load(f)

loaded_earthquake_data
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1702559275000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_week.geojson',
#   'title': 'USGS Magnitude 2.5+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.10.3',
#   'count': 320},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '51 km ESE of Cantwell, Alaska',
#     'time': 1702556706982,
#     'updated': 1702556810168,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fzqbcis',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fzqbcis.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'ak',
#     'code': '023fzqbcis',
#     'ids': ',ak023fzqbcis,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.6,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 51 km ESE of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.0612, 63.1641, 62.6]},
#    'id': 'ak023fzqbcis'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.91,
#     'place': '19 km SW of Stella, Puerto Rico',
#     'time': 1702555115050,
#     'updated': 1702557807710,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433888',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433888.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 130,
#     'net': 'pr',
#     'code': '71433888',
#     'ids': ',pr71433888,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 4,
#     'dmin': 0.1877,
#     'rms': 0.15,
#     'gap': 211,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 19 km SW of Stella, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-67.3911666666667, 18.2155, 7.75]},
#    'id': 'pr71433888'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '44 km ENE of Barcelona, Philippines',
#     'time': 1702554840941,
#     'updated': 1702556924040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liy7',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liy7.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liy7',
#     'ids': ',us7000liy7,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 32,
#     'dmin': 1.72,
#     'rms': 1.05,
#     'gap': 126,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 44 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8124, 8.288, 66.56]},
#    'id': 'us7000liy7'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.8,
#     'place': '46 km ENE of Barcelona, Philippines',
#     'time': 1702554360474,
#     'updated': 1702556022040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liy8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liy8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 354,
#     'net': 'us',
#     'code': '7000liy8',
#     'ids': ',us7000liy8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 1.769,
#     'rms': 0.84,
#     'gap': 138,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.8 - 46 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.7907, 8.3776, 57.942]},
#    'id': 'us7000liy8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '50 km ENE of Barcelona, Philippines',
#     'time': 1702550573468,
#     'updated': 1702552292040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lixx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lixx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lixx',
#     'ids': ',us7000lixx,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 44,
#     'dmin': 1.763,
#     'rms': 0.86,
#     'gap': 88,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 50 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8786, 8.2815, 59.486]},
#    'id': 'us7000lixx'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.52,
#     'place': '7 km ENE of Mayagüez, Puerto Rico',
#     'time': 1702550072930,
#     'updated': 1702558140179,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2023348000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2023348000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'pr',
#     'code': '2023348000',
#     'ids': ',pr2023348000,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 3,
#     'dmin': 0.2216,
#     'rms': 0.18,
#     'gap': 279,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 7 km ENE of Mayagüez, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.0786, 18.2258, 12]},
#    'id': 'pr2023348000'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': 'southern East Pacific Rise',
#     'time': 1702546184089,
#     'updated': 1702550490040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000livw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000livw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000livw',
#     'ids': ',us7000livw,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 29,
#     'dmin': 27.632,
#     'rms': 0.75,
#     'gap': 124,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - southern East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.7493, -56.0214, 10]},
#    'id': 'us7000livw'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.54,
#     'place': '10 km ENE of Petrolia, CA',
#     'time': 1702543273400,
#     'updated': 1702549635121,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73976006',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73976006.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 99,
#     'net': 'nc',
#     'code': '73976006',
#     'ids': ',nc73976006,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.04656,
#     'rms': 0.09,
#     'gap': 74,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 10 km ENE of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.1681671, 40.3515015, 22.93]},
#    'id': 'nc73976006'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '2 km WSW of Indios, Puerto Rico',
#     'time': 1702543064250,
#     'updated': 1702543658680,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433883',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433883.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'pr',
#     'code': '71433883',
#     'ids': ',pr71433883,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.03651,
#     'rms': 0.18,
#     'gap': 173,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 2 km WSW of Indios, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8411666666667, 17.9895, 15.74]},
#    'id': 'pr71433883'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '13 km SW of Khalmion, Kyrgyzstan',
#     'time': 1702540793045,
#     'updated': 1702542323040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000livf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000livf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000livf',
#     'ids': ',us7000livf,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.539,
#     'rms': 0.6,
#     'gap': 94,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 13 km SW of Khalmion, Kyrgyzstan'},
#    'geometry': {'type': 'Point', 'coordinates': [71.5122, 40.1392, 10]},
#    'id': 'us7000livf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '71 km SW of Pelabuhanratu, Indonesia',
#     'time': 1702538836338,
#     'updated': 1702540630040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liv9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liv9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000liv9',
#     'ids': ',us7000liv9,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 53,
#     'dmin': 1.617,
#     'rms': 0.78,
#     'gap': 119,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 71 km SW of Pelabuhanratu, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [106.0231, -7.3556, 56.624]},
#    'id': 'us7000liv9'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.79,
#     'place': '6 km S of Volcano, Hawaii',
#     'time': 1702537249740,
#     'updated': 1702552415114,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73684747',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73684747.geojson',
#     'felt': 2,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 120,
#     'net': 'hv',
#     'code': '73684747',
#     'ids': ',hv73684747,us7000liv7,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 33,
#     'dmin': None,
#     'rms': 0.280000001,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 6 km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2431640625, 19.386833190918, 0.939999997615814]},
#    'id': 'hv73684747'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': 'northern Mid-Atlantic Ridge',
#     'time': 1702536725137,
#     'updated': 1702538300040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liv6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liv6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000liv6',
#     'ids': ',us7000liv6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 64,
#     'dmin': 13.517,
#     'rms': 0.89,
#     'gap': 149,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - northern Mid-Atlantic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-46.3575, 17.2185, 10]},
#    'id': 'us7000liv6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '65 km SW of Ashkāsham, Afghanistan',
#     'time': 1702533896344,
#     'updated': 1702539470040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000liuz',
#     'ids': ',us7000liuz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 2.357,
#     'rms': 0.64,
#     'gap': 102,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 65 km SW of Ashkāsham, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [71.0523, 36.2362, 112.016]},
#    'id': 'us7000liuz'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '97 km ENE of Barcelona, Philippines',
#     'time': 1702533316874,
#     'updated': 1702537293040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liux',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liux.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liux',
#     'ids': ',us7000liux,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 2.209,
#     'rms': 0.44,
#     'gap': 112,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 97 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.2153, 8.5806, 10]},
#    'id': 'us7000liux'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '97 km E of Marihatag, Philippines',
#     'time': 1702532002509,
#     'updated': 1702536254040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liuu',
#     'ids': ',us7000liuu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': 2.246,
#     'rms': 0.53,
#     'gap': 128,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 97 km E of Marihatag, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.1705, 8.6793, 10]},
#    'id': 'us7000liuu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '88 km ENE of Barcelona, Philippines',
#     'time': 1702531600540,
#     'updated': 1702533806040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lius',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lius.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lius',
#     'ids': ',us7000lius,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 61,
#     'dmin': 2.134,
#     'rms': 0.62,
#     'gap': 122,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 88 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.1227, 8.5672, 10]},
#    'id': 'us7000lius'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '67 km SW of Tupiza, Bolivia',
#     'time': 1702530294553,
#     'updated': 1702531606040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lium',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lium.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000lium',
#     'ids': ',us7000lium,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 2.13,
#     'rms': 0.52,
#     'gap': 79,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 67 km SW of Tupiza, Bolivia'},
#    'geometry': {'type': 'Point', 'coordinates': [-66.2141, -21.8368, 251.836]},
#    'id': 'us7000lium'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '238 km SE of Chiniak, Alaska',
#     'time': 1702526424323,
#     'updated': 1702528908040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuf',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuf.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 1,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000liuf',
#     'ids': ',ak023fzlek7t,us7000liuf,',
#     'sources': ',ak,us,',
#     'types': ',origin,phase-data,shakemap,',
#     'nst': 109,
#     'dmin': 2.379,
#     'rms': 0.76,
#     'gap': 145,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 238 km SE of Chiniak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4338, 56.1479, 17.797]},
#    'id': 'us7000liuf'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '86 km ENE of Barcelona, Philippines',
#     'time': 1702524998048,
#     'updated': 1702526069040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liuc',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liuc.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000liuc',
#     'ids': ',us7000liuc,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 35,
#     'dmin': 2.092,
#     'rms': 0.59,
#     'gap': 129,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 86 km ENE of Barcelona, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [127.152, 8.4738, 65.664]},
#    'id': 'us7000liuc'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '6 km SSE of Qingsheng, China',
#     'time': 1702521543660,
#     'updated': 1702525053027,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liua',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liua.geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000liua',
#     'ids': ',us7000liua,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 39,
#     'dmin': 6.85,
#     'rms': 0.7,
#     'gap': 78,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 6 km SSE of Qingsheng, China'},
#    'geometry': {'type': 'Point', 'coordinates': [105.5421, 29.2665, 38.715]},
#    'id': 'us7000liua'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.94,
#     'place': '7 km SW of Volcano, Hawaii',
#     'time': 1702520751480,
#     'updated': 1702521975123,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73684282',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73684282.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 133,
#     'net': 'hv',
#     'code': '73684282',
#     'ids': ',hv73684282,us7000liu7,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 38,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 67,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 7 km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.277333333333, 19.3836666666667, 1.44]},
#    'id': 'hv73684282'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.64,
#     'place': '6 km SW of Volcano, Hawaii',
#     'time': 1702520234170,
#     'updated': 1702520565340,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73684257',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73684257.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 107,
#     'net': 'hv',
#     'code': '73684257',
#     'ids': ',hv73684257,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 36,
#     'dmin': None,
#     'rms': 0.239999995,
#     'gap': 41,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 6 km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.272506713867, 19.3933334350586, 0.990000009536743]},
#    'id': 'hv73684257'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.7,
#     'place': '16 km NE of Hermleigh, Texas',
#     'time': 1702517316105,
#     'updated': 1702518829865,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023ykcm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023ykcm.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 112,
#     'net': 'tx',
#     'code': '2023ykcm',
#     'ids': ',tx2023ykcm,us7000litw,',
#     'sources': ',tx,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 80,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 16 km NE of Hermleigh, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-100.647, 32.753, 8.4369]},
#    'id': 'tx2023ykcm'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '17 km NE of Hermleigh, Texas',
#     'time': 1702516488318,
#     'updated': 1702523256512,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023ykca',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023ykca.geojson',
#     'felt': 6,
#     'cdi': 4.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 225,
#     'net': 'tx',
#     'code': '2023ykca',
#     'ids': ',tx2023ykca,us7000lits,',
#     'sources': ',tx,us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.1,
#     'rms': 0.2,
#     'gap': 80,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 17 km NE of Hermleigh, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-100.642, 32.758, 7.85]},
#    'id': 'tx2023ykca'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '53 km SW of Modisi, Indonesia',
#     'time': 1702515949758,
#     'updated': 1702516908040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000litr',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000litr.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000litr',
#     'ids': ',us7000litr,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 76,
#     'dmin': 1.747,
#     'rms': 1.09,
#     'gap': 52,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 53 km SW of Modisi, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [124.0674, 0.1386, 107.163]},
#    'id': 'us7000litr'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.23,
#     'place': '89 km N of Brenas, Puerto Rico',
#     'time': 1702513327340,
#     'updated': 1702521040163,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433868',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433868.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 161,
#     'net': 'pr',
#     'code': '71433868',
#     'ids': ',pr71433868,',
#     'sources': ',pr,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.9502,
#     'rms': 0.14,
#     'gap': 246,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 89 km N of Brenas, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.3581666666667, 19.274, 20.26]},
#    'id': 'pr71433868'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.4,
#     'place': '92 km SSE of Alo, Wallis and Futuna',
#     'time': 1702510511291,
#     'updated': 1702511604040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lit3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lit3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 298,
#     'net': 'us',
#     'code': '7000lit3',
#     'ids': ',us7000lit3,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 41,
#     'dmin': 4.816,
#     'rms': 0.84,
#     'gap': 115,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.4 - 92 km SSE of Alo, Wallis and Futuna'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-177.7606, -15.0746, 381.121]},
#    'id': 'us7000lit3'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.8,
#     'place': '181 km WSW of Port Orford, Oregon',
#     'time': 1702505844857,
#     'updated': 1702510796040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lisu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lisu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 222,
#     'net': 'us',
#     'code': '7000lisu',
#     'ids': ',us7000lisu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 64,
#     'dmin': 1.697,
#     'rms': 0.54,
#     'gap': 250,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 3.8 - 181 km WSW of Port Orford, Oregon'},
#    'geometry': {'type': 'Point', 'coordinates': [-126.6367, 42.3439, 12.259]},
#    'id': 'us7000lisu'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.1,
#     'place': '91 km WSW of Copiapó, Chile',
#     'time': 1702502755365,
#     'updated': 1702507249040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liru',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liru.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 259,
#     'net': 'us',
#     'code': '7000liru',
#     'ids': ',us7000liru,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.478,
#     'rms': 0.62,
#     'gap': 191,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.1 - 91 km WSW of Copiapó, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1665, -27.7319, 30.508]},
#    'id': 'us7000liru'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '255 km S of Vailoatai, American Samoa',
#     'time': 1702498977042,
#     'updated': 1702542782126,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lirg',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lirg.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000lirg',
#     'ids': ',us7000lirg,',
#     'sources': ',us,',
#     'types': ',oaf,origin,phase-data,',
#     'nst': 45,
#     'dmin': 2.43,
#     'rms': 0.77,
#     'gap': 110,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 255 km S of Vailoatai, American Samoa'},
#    'geometry': {'type': 'Point', 'coordinates': [-170.9942, -16.6549, 3.095]},
#    'id': 'us7000lirg'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.5,
#     'place': 'Norwegian Sea',
#     'time': 1702498810818,
#     'updated': 1702506274043,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lire',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lire.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 465,
#     'net': 'us',
#     'code': '7000lire',
#     'ids': ',us7000lire,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 103,
#     'dmin': 6.49,
#     'rms': 0.77,
#     'gap': 29,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.5 - Norwegian Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [3.4844, 72.5721, 10]},
#    'id': 'us7000lire'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.3,
#     'place': 'Norwegian Sea',
#     'time': 1702495846888,
#     'updated': 1702496891040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lir5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lir5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 432,
#     'net': 'us',
#     'code': '7000lir5',
#     'ids': ',us7000lir5,',
#     'sources': ',us,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 145,
#     'dmin': 6.509,
#     'rms': 0.85,
#     'gap': 34,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.3 - Norwegian Sea'},
#    'geometry': {'type': 'Point', 'coordinates': [3.45, 72.5552, 10]},
#    'id': 'us7000lir5'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.61,
#     'place': '3 km ENE of Pāhala, Hawaii',
#     'time': 1702490206540,
#     'updated': 1702504237030,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73683582',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73683582.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 105,
#     'net': 'hv',
#     'code': '73683582',
#     'ids': ',hv73683582,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 45,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 124,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 3 km ENE of Pāhala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.443, 19.2101666666667, 34.82]},
#    'id': 'hv73683582'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.92,
#     'place': '11 km SW of Volcano, Hawaii',
#     'time': 1702486224450,
#     'updated': 1702509969040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73683477',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73683477.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 131,
#     'net': 'hv',
#     'code': '73683477',
#     'ids': ',us7000liq5,hv73683477,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 21,
#     'dmin': None,
#     'rms': 0.09,
#     'gap': 100,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 11 km SW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.301, 19.3596666666667, 2.18]},
#    'id': 'hv73683477'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.2,
#     'place': '96 km NNW of Batang, Indonesia',
#     'time': 1702483739523,
#     'updated': 1702510965040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000liq0',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000liq0.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 271,
#     'net': 'us',
#     'code': '7000liq0',
#     'ids': ',us7000liq0,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 3.284,
#     'rms': 0.9,
#     'gap': 42,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.2 - 96 km NNW of Batang, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [110.4186, -5.6571, 551.302]},
#    'id': 'us7000liq0'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.7,
#     'place': '48 km W of Mentone, Texas',
#     'time': 1702482478968,
#     'updated': 1702483441040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023yjji',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023yjji.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 211,
#     'net': 'tx',
#     'code': '2023yjji',
#     'ids': ',us7000lipx,tx2023yjji,',
#     'sources': ',us,tx,',
#     'types': ',moment-tensor,origin,phase-data,',
#     'nst': 17,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 72,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.7 - 48 km W of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.112, 31.738, 7.0056]},
#    'id': 'tx2023yjji'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.74,
#     'place': '6 km S of Volcano, Hawaii',
#     'time': 1702478018170,
#     'updated': 1702488584510,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73683272',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73683272.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 116,
#     'net': 'hv',
#     'code': '73683272',
#     'ids': ',hv73683272,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': None,
#     'rms': 0.1,
#     'gap': 77,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 6 km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.243833333333, 19.3871666666667, 1.64]},
#    'id': 'hv73683272'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '222 km NE of Lospalos, Timor Leste',
#     'time': 1702477853172,
#     'updated': 1702481817040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lipp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lipp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lipp',
#     'ids': ',us7000lipp,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 83,
#     'dmin': 3.084,
#     'rms': 0.85,
#     'gap': 51,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 222 km NE of Lospalos, Timor Leste'},
#    'geometry': {'type': 'Point', 'coordinates': [128.6454, -7.3596, 147.747]},
#    'id': 'us7000lipp'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '54 km NNE of Chase, Alaska',
#     'time': 1702473908561,
#     'updated': 1702555842040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fy3dfs8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fy3dfs8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '023fy3dfs8',
#     'ids': ',us7000lime,ak023fy3dfs8,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.77,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 54 km NNE of Chase, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.5878, 62.8783, 0]},
#    'id': 'ak023fy3dfs8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '19 km NNE of Kandrian, Papua New Guinea',
#     'time': 1702469553375,
#     'updated': 1702470615040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lim6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lim6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000lim6',
#     'ids': ',us7000lim6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 37,
#     'dmin': 3.145,
#     'rms': 0.92,
#     'gap': 121,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 19 km NNE of Kandrian, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [149.6001, -6.0387, 63.877]},
#    'id': 'us7000lim6'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.53,
#     'place': '16 km ENE of Wailua, Hawaii',
#     'time': 1702463193210,
#     'updated': 1702557974040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73682967',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73682967.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 98,
#     'net': 'hv',
#     'code': '73682967',
#     'ids': ',us7000lirv,hv73682967,',
#     'sources': ',us,hv,',
#     'types': ',origin,phase-data,',
#     'nst': 32,
#     'dmin': None,
#     'rms': 0.27,
#     'gap': 220,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 16 km ENE of Wailua, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.997666666667, 20.9263333333333, 34.24]},
#    'id': 'hv73682967'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '39 km WSW of Mentone, Texas',
#     'time': 1702462725724,
#     'updated': 1702496029862,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023yiym',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023yiym.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2023yiym',
#     'ids': ',tx2023yiym,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0,
#     'rms': 0.1,
#     'gap': 54,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 39 km WSW of Mentone, Texas'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.012, 31.634, 5.656]},
#    'id': 'tx2023yiym'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.08,
#     'place': '2 km SSE of Magas Arriba, Puerto Rico',
#     'time': 1702461347160,
#     'updated': 1702462569620,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71433838',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr71433838.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 146,
#     'net': 'pr',
#     'code': '71433838',
#     'ids': ',pr71433838,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 20,
#     'dmin': 0.03921,
#     'rms': 0.17,
#     'gap': 167,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 2 km SSE of Magas Arriba, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.7573333333333, 17.998, 12.41]},
#    'id': 'pr71433838'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '111 km NNE of Finschhafen, Papua New Guinea',
#     'time': 1702455206651,
#     'updated': 1702457134040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lil8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lil8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lil8',
#     'ids': ',us7000lil8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 3.889,
#     'rms': 0.94,
#     'gap': 50,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 111 km NNE of Finschhafen, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [148.3144, -5.6633, 170.313]},
#    'id': 'us7000lil8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '57 km NE of Bandar-e Lengeh, Iran',
#     'time': 1702452785082,
#     'updated': 1702456623040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lil6',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lil6.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '7000lil6',
#     'ids': ',us7000lil6,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 2.112,
#     'rms': 0.64,
#     'gap': 109,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 57 km NE of Bandar-e Lengeh, Iran'},
#    'geometry': {'type': 'Point', 'coordinates': [55.3048, 26.9039, 10]},
#    'id': 'us7000lil6'},
#   {'type': 'Feature',
#    'properties': {'mag': 4,
#     'place': '144 km N of Cruz Bay, U.S. Virgin Islands',
#     'time': 1702451832100,
#     'updated': 1702454037040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2023347000',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2023347000.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 246,
#     'net': 'pr',
#     'code': '2023347000',
#     'ids': ',us7000lil2,pr2023347000,',
#     'sources': ',us,pr,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 1.211,
#     'rms': 0.35,
#     'gap': 288,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 4.0 - 144 km N of Cruz Bay, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.587, 19.6256, 62]},
#    'id': 'pr2023347000'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.5,
#     'place': '2 km NNE of The Geysers, CA',
#     'time': 1702450339610,
#     'updated': 1702490551188,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73975501',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73975501.geojson',
#     'felt': 24,
#     'cdi': 3.8,
#     'mmi': 4.272,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 198,
#     'net': 'nc',
#     'code': '73975501',
#     'ids': ',nc73975501,us7000likr,',
#     'sources': ',nc,us,',
#     'types': ',dyfi,focal-mechanism,moment-tensor,nearby-cities,origin,phase-data,scitech-link,shakemap,',
#     'nst': 109,
#     'dmin': 0.01136,
#     'rms': 0.07,
#     'gap': 26,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 3.5 - 2 km NNE of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.746, 38.7968333, 0.34]},
#    'id': 'nc73975501'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'Volcano Islands, Japan region',
#     'time': 1702449607456,
#     'updated': 1702452029040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000likz',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000likz.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000likz',
#     'ids': ',us7000likz,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 40,
#     'dmin': 13.041,
#     'rms': 0.96,
#     'gap': 95,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - Volcano Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [142.525, 23.0918, 10.36]},
#    'id': 'us7000likz'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.4,
#     'place': 'southern East Pacific Rise',
#     'time': 1702439750436,
#     'updated': 1702526359158,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lik3',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lik3.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 449,
#     'net': 'us',
#     'code': '7000lik3',
#     'ids': ',us7000lik3,',
#     'sources': ',us,',
#     'types': ',losspager,origin,phase-data,shakemap,',
#     'nst': 51,
#     'dmin': 39.039,
#     'rms': 0.59,
#     'gap': 113,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.4 - southern East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.0832, -25.5803, 10]},
#    'id': 'us7000lik3'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '134 km S of Isangel, Vanuatu',
#     'time': 1702436660327,
#     'updated': 1702437688040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lijx',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lijx.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000lijx',
#     'ids': ',us7000lijx,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 2.611,
#     'rms': 0.9,
#     'gap': 163,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 134 km S of Isangel, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [169.4222, -20.7494, 35]},
#    'id': 'us7000lijx'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'Reykjanes Ridge',
#     'time': 1702436316402,
#     'updated': 1702439034040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lik1',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lik1.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lik1',
#     'ids': ',us7000lik1,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': 24.22,
#     'rms': 0.54,
#     'gap': 113,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - Reykjanes Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [-34.438, 56.6366, 10]},
#    'id': 'us7000lik1'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.99,
#     'place': '33 km NNW of Challis, Idaho',
#     'time': 1702435218690,
#     'updated': 1702483894660,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb90036128',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb90036128.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 138,
#     'net': 'mb',
#     'code': '90036128',
#     'ids': ',mb90036128,',
#     'sources': ',mb,',
#     'types': ',origin,phase-data,',
#     'nst': 49,
#     'dmin': 0.4545,
#     'rms': 0.23,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 33 km NNW of Challis, Idaho'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-114.407666666667, 44.7746666666667, 11.97]},
#    'id': 'mb90036128'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '62 km S of Whites City, New Mexico',
#     'time': 1702432232543,
#     'updated': 1702487517238,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2023yiht',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/tx2023yiht.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'tx',
#     'code': '2023yiht',
#     'ids': ',tx2023yiht,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 24,
#     'dmin': 0,
#     'rms': 0.2,
#     'gap': 69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 62 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-104.497, 31.624, 7.417]},
#    'id': 'tx2023yiht'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '51 km SSW of Whites City, New Mexico',
#     'time': 1702422336052,
#     'updated': 1702509176551,
#     'tz': None,
# ...
#    'id': 'us7000lh76'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.2,
#     'place': '47 km S of Yakutat, Alaska',
#     'time': 1701984948048,
#     'updated': 1701985550040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023foaz1v8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023foaz1v8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 158,
#     'net': 'ak',
#     'code': '023foaz1v8',
#     'ids': ',us7000lh66,ak023foaz1v8,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.59,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.2 - 47 km S of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-139.8578, 59.1298, 9.1]},
#    'id': 'ak023foaz1v8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': '157 km NNW of Las Khorey, Somalia',
#     'time': 1701981799094,
#     'updated': 1701984482040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh5r',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh5r.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lh5r',
#     'ids': ',us7000lh5r,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 60,
#     'dmin': 4.599,
#     'rms': 0.45,
#     'gap': 99,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - 157 km NNW of Las Khorey, Somalia'},
#    'geometry': {'type': 'Point', 'coordinates': [47.465, 12.3893, 10]},
#    'id': 'us7000lh5r'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.56,
#     'place': '1 km S of Banning, CA',
#     'time': 1701979913050,
#     'updated': 1702217787040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40617352',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci40617352.geojson',
#     'felt': 6,
#     'cdi': 3.1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 103,
#     'net': 'ci',
#     'code': '40617352',
#     'ids': ',ci40617352,us7000lh57,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 100,
#     'dmin': 0.07825,
#     'rms': 0.16,
#     'gap': 22,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.6 - 1 km S of Banning, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.878, 33.9186667, 9.97]},
#    'id': 'ci40617352'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.8,
#     'place': '10 km NNE of Chiautla de Tapia, Mexico',
#     'time': 1701979418206,
#     'updated': 1702402064637,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh50',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh50.geojson',
#     'felt': 198,
#     'cdi': 8.1,
#     'mmi': 5.293,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 678,
#     'net': 'us',
#     'code': '7000lh50',
#     'ids': ',us7000lh50,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 175,
#     'dmin': 0.82,
#     'rms': 0.64,
#     'gap': 99,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.8 - 10 km NNE of Chiautla de Tapia, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-98.5503, 18.3866, 44.388]},
#    'id': 'us7000lh50'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '66 km E of Marihatag, Philippines',
#     'time': 1701977244980,
#     'updated': 1701987692045,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh4x',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh4x.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000lh4x',
#     'ids': ',us7000lh4x,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 37,
#     'dmin': 2.112,
#     'rms': 0.51,
#     'gap': 154,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 66 km E of Marihatag, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.8955, 8.7418, 58.314]},
#    'id': 'us7000lh4x'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.2,
#     'place': 'Kermadec Islands region',
#     'time': 1701976335075,
#     'updated': 1701978155040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lh4u',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lh4u.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 416,
#     'net': 'us',
#     'code': '7000lh4u',
#     'ids': ',us7000lh4u,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 1.979,
#     'rms': 1.09,
#     'gap': 173,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.2 - Kermadec Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.1087, -31.241, 10]},
#    'id': 'us7000lh4u'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.43,
#     'place': '78 km SSW of Mākena, Hawaii',
#     'time': 1701975255910,
#     'updated': 1701981400040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73676237',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73676237.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 181,
#     'net': 'hv',
#     'code': '73676237',
#     'ids': ',hv73676237,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 53,
#     'dmin': None,
#     'rms': 0.18,
#     'gap': 304,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.4 - 78 km SSW of Mākena, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-156.760333333333, 20.0155, 38.06]},
#    'id': 'hv73676237'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.63,
#     'place': 'Island of Hawaii, Hawaii',
#     'time': 1701969216550,
#     'updated': 1702072659784,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73675997',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv73675997.geojson',
#     'felt': 69,
#     'cdi': 3.4,
#     'mmi': 4.101,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 226,
#     'net': 'hv',
#     'code': '73675997',
#     'ids': ',hv73675997,us7000lh41,',
#     'sources': ',hv,us,',
#     'types': ',dyfi,origin,phase-data,shakemap,',
#     'nst': 24,
#     'dmin': None,
#     'rms': 0.11,
#     'gap': 163,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.6 - Island of Hawaii, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.3855, 19.2466666666667, 32.85]},
#    'id': 'hv73675997'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.5,
#     'place': '24 km S of Denali National Park, Alaska',
#     'time': 1701966892256,
#     'updated': 1702149684040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fo7zofm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fo7zofm.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 96,
#     'net': 'ak',
#     'code': '023fo7zofm',
#     'ids': ',us7000lgyc,ak023fo7zofm,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.68,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.5 - 24 km S of Denali National Park, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.7765, 63.3238, 0]},
#    'id': 'ak023fo7zofm'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.7,
#     'place': 'Bonin Islands, Japan region',
#     'time': 1701965115195,
#     'updated': 1701968981040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgy8',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgy8.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 340,
#     'net': 'us',
#     'code': '7000lgy8',
#     'ids': ',us7000lgy8,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 43,
#     'dmin': 8.724,
#     'rms': 0.44,
#     'gap': 156,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.7 - Bonin Islands, Japan region'},
#    'geometry': {'type': 'Point', 'coordinates': [142.5971, 28.6173, 10]},
#    'id': 'us7000lgy8'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '272 km N of Tobelo, Indonesia',
#     'time': 1701963485751,
#     'updated': 1701972127040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxv',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxv.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000lgxv',
#     'ids': ',us7000lgxv,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 31,
#     'dmin': 3.422,
#     'rms': 0.49,
#     'gap': 83,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 272 km N of Tobelo, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [127.8335, 4.1846, 116.281]},
#    'id': 'us7000lgxv'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '68 km NW of Lecherías, Venezuela',
#     'time': 1701962615923,
#     'updated': 1701983268401,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxw.geojson',
#     'felt': 1,
#     'cdi': 1,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000lgxw',
#     'ids': ',us7000lgxw,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 46,
#     'dmin': 5.591,
#     'rms': 0.73,
#     'gap': 64,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 68 km NW of Lecherías, Venezuela'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.0735, 10.6797, 10]},
#    'id': 'us7000lgxw'},
#   {'type': 'Feature',
#    'properties': {'mag': 5,
#     'place': '106 km ENE of Angoram, Papua New Guinea',
#     'time': 1701961812503,
#     'updated': 1702148842040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxs',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxs.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 385,
#     'net': 'us',
#     'code': '7000lgxs',
#     'ids': ',us7000lgxs,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 80,
#     'dmin': 4.372,
#     'rms': 0.65,
#     'gap': 69,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.0 - 106 km ENE of Angoram, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [144.932, -3.6526, 10]},
#    'id': 'us7000lgxs'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '51 km ENE of Hinatuan, Philippines',
#     'time': 1701961718582,
#     'updated': 1701964597040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxq',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxq.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000lgxq',
#     'ids': ',us7000lgxq,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 123,
#     'dmin': 1.877,
#     'rms': 0.88,
#     'gap': 81,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 51 km ENE of Hinatuan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.7696, 8.5387, 52.726]},
#    'id': 'us7000lgxq'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '71 km SE of Taoluo, China',
#     'time': 1701961306153,
#     'updated': 1702147397040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxu',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxu.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000lgxu',
#     'ids': ',us7000lgxu,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 122,
#     'dmin': 5.977,
#     'rms': 0.69,
#     'gap': 73,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 71 km SE of Taoluo, China'},
#    'geometry': {'type': 'Point', 'coordinates': [119.9504, 34.8443, 10]},
#    'id': 'us7000lgxu'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.1,
#     'place': '132 km NW of Las Khorey, Somalia',
#     'time': 1701960542089,
#     'updated': 1701961448040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxl',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 400,
#     'net': 'us',
#     'code': '7000lgxl',
#     'ids': ',us7000lgxl,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 28,
#     'dmin': 4.616,
#     'rms': 1.03,
#     'gap': 137,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 5.1 - 132 km NW of Las Khorey, Somalia'},
#    'geometry': {'type': 'Point', 'coordinates': [47.5191, 12.1512, 10]},
#    'id': 'us7000lgxl'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '23 km ENE of Hinatuan, Philippines',
#     'time': 1701958297687,
#     'updated': 1701962249040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000lgxi',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000lgxi.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '7000lgxi',
#     'ids': ',us7000lgxi,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 22,
#     'dmin': 1.658,
#     'rms': 0.78,
#     'gap': 130,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 23 km ENE of Hinatuan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5341, 8.4399, 76.878]},
#    'id': 'us7000lgxi'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.9,
#     'place': '48 km SE of Port Graham, Alaska',
#     'time': 1701954652211,
#     'updated': 1701961706040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak023fo628g5',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak023fo628g5.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 129,
#     'net': 'ak',
#     'code': '023fo628g5',
#     'ids': ',us7000lgws,ak023fo628g5,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.65,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.9 - 48 km SE of Port Graham, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2231, 59.043, 37.6]},
#    'id': 'ak023fo628g5'}],
#  'bbox': [-179.2278, -60.3806, -0.13, 179.2842, 72.5721, 569.73]}
